# %% [markdown]
# Objectives :
# 1. Welcome Message:
# - The program starts by greeting, setting the stage for the ATM simulation.
#
# 2. Initialize Account Balance:
# - The balance variable is set to 1000, representing the user's starting account balance.
#
# 3. Set Up and Verify PIN:
# - The user_pin variable holds the correct PIN ('1234').
# - The user is prompted to enter their PIN.
# - The entered PIN is compared to user_pin.
# - If the PIN is incorrect, the program notifies and sets atm_on to False to prevent entering the main loop.
# - If the PIN is correct, atm_on is set to True, allowing access to the ATM functionalities.
#
# 4. Main ATM Operation Loop:
# - A while loop is used, controlled by the atm_on flag.
# - Inside the loop, the main menu is displayed with options to check balance, deposit money, withdraw money, or exit.
#
# 5. User Choice Handling:
# - The user's choice is captured through input.
# - if-elif-else statements handle the different choices.
#
# 6. Balance Inquiry:
# - If the user chooses to check the balance, it's displayed using the balance variable.
#
# Objectives :
# 7. Deposit Money:
# - The user can deposit money, which is added to balance.
# - The deposit amount and updated balance are displayed.
#
# 8. Withdraw Money:
# - For withdrawals, the program checks if the balance is sufficient .
# - If so, the requested amount is subtracted from balance, and the withdrawal is confirmed.
# - If the balance is insufficient, a warning message is shown.
#
# 9. Exiting the Program:
# - The user can choose to exit the ATM.
# - On exiting, a goodbye message is shown, and atm_on is set to False, ending the loop and the program.
#
# 10. Invalid Choice Handling:
# - If the user enters an option that's not on the menu, the program prompts them to try again.

# %%
# Welcome Message
print("Welcome to the ATM simulation!")

# Initialize Account Balance
balance = 1000

# Set Up and Verify PIN
user_pin = '1234'
entered_pin = input("Please enter your PIN: ")
if entered_pin != user_pin:
    print("Incorrect PIN. Access denied.")
    atm_on = False
else:
    print("PIN verified. Access granted.")
    atm_on = True

# Main ATM Operation Loop
while atm_on:
    # Display Main Menu
    print("Main Menu:")
    print("1. Check Balance")
    print("2. Deposit Money")
    print("3. Withdraw Money")
    print("4. Exit")

    # User Choice Handling
    choice = input("Please enter your choice: ")

    if choice == '1':
        # Balance Inquiry
        print("Your current balance is:", balance)
    elif choice == '2':
        # Deposit Money
        deposit_amount = float(input("Enter the amount to deposit: "))
        balance += deposit_amount
        print("Deposit successful. Your updated balance is:", balance)
    elif choice == '3':
        # Withdraw Money
        withdrawal_amount = float(input("Enter the amount to withdraw: "))
        if withdrawal_amount <= balance:
            balance -= withdrawal_amount
            print("Withdrawal successful. Your updated balance is:", balance)
        else:
            print("Insufficient balance. Withdrawal canceled.")
    elif choice == '4':
        # Exiting the Program
        print("Thank you for using the ATM. Goodbye!")
        atm_on = False
    else:
        # Invalid Choice Handling
        print("Invalid choice. Please try again.")

# %%
def atm_simulation():
    # Welcome Message
    print("Welcome to the ATM simulation!")

    # Initialize Account Balance
    balance = 1000

    # Set Up and Verify PIN
    user_pin = '1234'
    entered_pin = input("Please enter your PIN: ")
    
    # Verify PIN
    if entered_pin == user_pin:
        print("PIN verified. Access granted.")
        atm_on = True
    else:
        print("Incorrect PIN. Access denied.")
        atm_on = False

    # Main ATM Operation Loop
    while atm_on:
        # Display Main Menu
        print("Main Menu:")
        print("1. Check Balance")
        print("2. Deposit Money")
        print("3. Withdraw Money")
        print("4. Exit")

        # User Choice Handling
        choice = input("Please enter your choice: ")

        # Match pattern for user choice
        match choice:
            case '1':
                # Balance Inquiry
                print("Your current balance is:", balance)
            case '2':
                # Deposit Money
                deposit_amount = float(input("Enter the amount to deposit: "))
                balance += deposit_amount
                print("Deposit successful. Your updated balance is:", balance)
            case '3':
                # Withdraw Money
                withdrawal_amount = float(input("Enter the amount to withdraw: "))
                if withdrawal_amount <= balance:
                    balance -= withdrawal_amount
                    print("Withdrawal successful. Your updated balance is:", balance)
                else:
                    print("Insufficient balance. Withdrawal canceled.")
            case '4':
                # Exiting the Program
                print("Thank you for using the ATM. Goodbye!")
                atm_on = False
            case _:
                # Invalid Choice Handling
                print("Invalid choice. Please try again.")

# %%
atm_simulation()

# %%
# %pip install -r requirements.txt
